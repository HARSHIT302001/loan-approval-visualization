# %% [markdown]
# # LOAN APPROVAL ANALYSIS.

# %% [markdown]
# ## DATA EXPLORATION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('loan_sanction_test.csv')
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %% [markdown]
# ## BASIC INFOMATION ABOUT DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
df.shape
# Out:
# (367, 12)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
df.tail()
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 362             1.0         Urban
# 363             1.0         Urban
# ...

# %%
df.sample(5)
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 230  LP002294   Male      No          0  Graduate            No
# 231  LP002298    NaN      No          0  Graduate           Yes
# 3    LP001035   Male     Yes          2  Graduate            No
# 0    LP001015   Male     Yes          0  Graduate            No
# 243  LP002346   Male     Yes          0  Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 230            14911              14507       130.0             360.0
# 231             2860               2988       138.0             360.0
# 3               2340               2546       100.0             360.0
# 0               5720                  0       110.0             360.0
# 243             2539               1704       125.0             360.0
#
#      Credit_History Property_Area
# 230             1.0     Semiurban
# 231             1.0         Urban
# 3               NaN         Urban
# ...

# %%
df.describe(include="O")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        367    356     367        357       367           344
# unique       367      2       2          4         2             2
# top     LP001015   Male     Yes          0  Graduate            No
# freq           1    286     233        200       283           307
#
#        Property_Area
# count            367
# unique             3
# top            Urban
# freq             140

# %%
df.describe( include ='all')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        367    356     367        357       367           344
# unique       367      2       2          4         2             2
# top     LP001015   Male     Yes          0  Graduate            No
# freq           1    286     233        200       283           307
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        367.000000         367.000000  362.000000        361.000000
# ...

# %% [markdown]
# ## CHECK FOR MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
df.isnull().sum() / len(df) * 100
# Out:
# Loan_ID              0.000000
# Gender               2.997275
# Married              0.000000
# Dependents           2.724796
# Education            0.000000
# Self_Employed        6.267030
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           1.362398
# Loan_Amount_Term     1.634877
# Credit_History       7.901907
# Property_Area        0.000000
# dtype: float64

# %%
# Fill missing values
for col in df.columns:
    if df[col].dtype == "object":
        df[col].fillna(df[col].mode()[0], inplace=True)  # Fill categorical columns with mode
    else:      
        df[col].fillna(df[col].mean(), inplace=True)  # Fill numeric columns with mean

# Check if missing values are handled
print("Missing values after handling:\n", df.isnull().sum())
# Out:
#   Cell In[23], line 8
#     print("Missing values after handling:\n", df.isnull().sum()
#                                                                ^
# SyntaxError: incomplete input

# %% [markdown]
# ## SUMMARY STATISTICS

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
# Select numeric columns
numeric_df = df.select_dtypes(include=["number"])

# Compute summary statistics
summary_statistics = numeric_df.describe().T
summary_statistics["median"] = numeric_df.median(numeric_only=True)

# Display the summary
print("Summary Statistics:\n", summary_statistics)
# Out:
# Summary Statistics:
#                     count         mean          std   min      25%     50%  \
# ApplicantIncome    367.0  4805.599455  4910.685399   0.0  2864.00  3786.0
# CoapplicantIncome  367.0  1569.577657  2334.232099   0.0     0.00  1025.0
# LoanAmount         362.0   136.132597    61.366652  28.0   100.25   125.0
# Loan_Amount_Term   361.0   342.537396    65.156643   6.0   360.00   360.0
# Credit_History     338.0     0.825444     0.380150   0.0     1.00     1.0
#
#                       75%      max  median
# ApplicantIncome    5060.0  72529.0  3786.0
# CoapplicantIncome  2430.5  24000.0  1025.0
# LoanAmount          158.0    550.0   125.0
# Loan_Amount_Term    360.0    480.0   360.0
# Credit_History        1.0      1.0     1.0

# %% [markdown]
# ### This will output:
#
# Mean,
# Standard deviation,
# Minimum and maximum values,
# Median

# %% [markdown]
# #### SUMMARY FOR CATEGORICAL VALUES

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()

# %%
df.nunique()
# Out:
# Loan_ID              367
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      314
# CoapplicantIncome    194
# LoanAmount           144
# Loan_Amount_Term      12
# Credit_History         2
# Property_Area          3
# dtype: int64

# %% [markdown]
# ## CHECK FOR DUPLICATES

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## DATA TYPE CONVERSION

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome      int64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# dtype: object

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("loan_sanction_test.csv")  # Change path if needed

# Check current data types
print("Before conversion:\n", df.dtypes)

# Convert Loan_Amount_Term and Credit_History to integer type
df["Loan_Amount_Term"] = df["Loan_Amount_Term"].astype("Int64")  # Allows NaN values
df["Credit_History"] = df["Credit_History"].astype("Int64")  # Allows NaN values

# Check updated data types
print("\nAfter conversion:\n", df.dtypes)
# Out:
# Before conversion:
#  Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome      int64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# dtype: object
#
# After conversion:
#  Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome      int64
# LoanAmount           float64
# Loan_Amount_Term       Int64
# Credit_History         Int64
# Property_Area         object
# dtype: object

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %% [markdown]
# ### DISTRIBUTION OF NUMERICAL COLUMNS

# %%
# List of numerical columns
numeric_columns = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

# Histogram & KDE Plot
plt.figure(figsize=(12, 8))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df[col].dropna(), bins=30, kde=True, color="blue")
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# Box Plots
plt.figure(figsize=(12, 6))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x=df[col], color='green')
    plt.title(f'Box Plot of {col}')
plt.tight_layout()
plt.show()

# Pairplot to check relationships
sns.pairplot(df[numeric_columns], diag_kind='kde')
plt.show()

# %% [markdown]
# ### FREQUENCY DISTRIBUTION

# %%
df = pd.read_csv("loan_sanction_test.csv")

# List of numeric columns
numeric_columns = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

# Histograms
plt.figure(figsize=(10, 6))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df[col].dropna(), bins=20, kde=True, color="blue")
    plt.title(f'{col} Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### POTENTIAL OUTLIERS AND VISUAL SPREAD OF DATA

# %%
# List of numeric columns
numeric_columns = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

# Box Plots
plt.figure(figsize=(10, 6))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x=df[col], color='green')
    plt.title(f'{col} Box Plot')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### DISTRIBUTION OF CATEGORICAL VARIABLES

# %%
# List of categorical columns
categorical_columns = ['Gender', 'Married', 'Education', 'Self_Employed', 'Property_Area']

# Bar Charts
plt.figure(figsize=(10, 6))
for i, col in enumerate(categorical_columns, 1):
    plt.subplot(2, 3, i)
    sns.countplot(x=df[col], palette="viridis")
    plt.title(f'{col} Count')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5056\4085923911.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], palette="viridis")
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5056\4085923911.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], palette="viridis")
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5056\4085923911.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], palette="viridis")
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5056\4085923911.py:15: FutureWarning:
#
# ...

# %% [markdown]
# ### VIOLIN PLOT

# %%
# List of numeric columns
numeric_columns = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

# Violin Plots
plt.figure(figsize=(10, 6))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(2, 2, i)
    sns.violinplot(y=df[col], color='blue')
    plt.title(f'{col} Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## MULTIVARIATE ANALYSIS

# %% [markdown]
# ### CORRELATION RELATIONSHIP BETWEEN NUMERIC VARIABLE

# %%
# Correlation Analysis
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### CORRELATION USING A HEATMAP

# %%
# Correlation Heatmap
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.show()

# %% [markdown]
# ### DISTRIBUTION OF CATEGORICAL VARIABLE ACROSS MULTIPLE

# %%
# Stacked Bar Chart
cat_cols = ['Gender', 'Married', 'Education', 'Self_Employed', 'Property_Area']
plt.figure(figsize=(10, 6))
for i, col in enumerate(cat_cols, 1):
    plt.subplot(2, 3, i)
    df[col].value_counts(normalize=True).plot(kind='bar', stacked=True, colormap='viridis')
    plt.title(f'{col} Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusion of the Loan Approval EDA Project
#
# Based on the exploratory data analysis (EDA) conducted on the home loan approval dataset, the following insights were derived:
#
# Data Quality and Preprocessing:
#
# Some missing values were identified in the dataset. Handling these missing values (either by imputation or removal) is essential.
# There were duplicate records in the dataset, which should be removed for better accuracy in analysis.
# Numerical Feature Analysis:
#
# The distribution of numerical features showed skewness in certain variables, indicating the presence of extreme values.
# Boxplots revealed the presence of outliers in some financial variables, which may need further investigation.
# Categorical Feature Analysis:
#
# Some categorical variables had an imbalanced distribution, meaning certain loan categories were significantly more frequent than others.
# Bar charts helped visualize the most common categories, providing insights into loan approval trends.
# Correlation Analysis:
#
# The correlation heatmap indicated that certain numerical variables had strong relationships. For example, income and loan amount might be positively correlated.
# Weak correlations among other variables suggest that additional external factors might influence loan approvals.
# Potential Next Steps:
#
# Feature engineering could help improve predictive modeling by creating new meaningful variables.
# Outliers could be handled using techniques like transformation or capping.
# Advanced modeling techniques, such as machine learning algorithms, could be applied to predict loan approval outcomes.
#
#
# # Final Thoughts:
# The analysis provides an overview of the trends and relationships within the dataset. It sets a strong foundation for further predictive modeling or business decision-making regarding loan approvals.
